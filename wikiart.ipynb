# %% [markdown]
# # WikiArt: Data Processing and EDA

# %%
import pandas as pd
import numpy as np
import plotly.express as px

# %%
wikiart_original = pd.read_csv('/Users/annielou/Desktop/General Assembly/unit4-project-capstone/wikiart_scraped.csv')

# %%
wikiart_original.describe()
# Out:
#               Style   Artwork                      Artist          Date  \
# count        124170    124170                      124170        124170
# unique          217     92050                        3052          2959
# top     Romanticism  Untitled  Giovanni Battista Piranesi  XIX-XX cent.
# freq           3600      4794                        1352          5713
#
#                                                      Link
# count                                              124170
# unique                                             116667
# top     https://uploads.wikiart.org/Content/wiki/img/l...
# freq                                                   54

# %%
wikiart_original.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 124170 entries, 0 to 124169
# Data columns (total 5 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   Style    124170 non-null  object
#  1   Artwork  124170 non-null  object
#  2   Artist   124170 non-null  object
#  3   Date     124170 non-null  object
#  4   Link     124170 non-null  object
# dtypes: object(5)
# memory usage: 4.7+ MB

# %%
wikiart_original.head(10)
# Out:
#             Style                                            Artwork  \
# 0  Early-Dynastic                                     Narmer Palette
# 1  Early-Dynastic                 Box Inlay with a Geometric Pattern
# 2     Old-Kingdom                                   Khafre Enthroned
# 3  Middle-Kingdom          Stele of the Serpent King (Stela of Djet)
# 4  Middle-Kingdom          Laden Donkeys and Ploughing, Tomb of Djar
# 5  Middle-Kingdom                Women Preparing Food, Tomb of Djari
# 6  Middle-Kingdom                                     Stela of a Man
# 7  Middle-Kingdom  Relief Fragment Showing a Pile of Offerings an...
# 8  Middle-Kingdom             Stela of Intef and His Wife, Dedetamun
# 9  Middle-Kingdom  Scarab with the Name of Amenemhat III and a Hi...
#
#           Artist          Date  \
# 0  Ancient Egypt       3050 BC
# 1  Ancient Egypt  3100-2900 BC
# 2  Ancient Egypt       2570 BC
# 3  Ancient Egypt       3000 BC
# 4  Ancient Egypt  2060-2010 BC
# 5  Ancient Egypt  2060-2010 BC
# 6  Ancient Egypt  2030-1981 BC
# 7  Ancient Egypt  2000-1981 BC
# 8  Ancient Egypt  1981-1802 BC
# 9  Ancient Egypt  1859-1749 BC
#
#                                                 Link
# 0  https://uploads3.wikiart.org/00265/images/anci...
# 1  https://uploads2.wikiart.org/00244/images/anci...
# 2  https://uploads2.wikiart.org/00305/images/anci...
# 3  https://uploads7.wikiart.org/00305/images/anci...
# 4  https://uploads8.wikiart.org/00244/images/anci...
# 5  https://uploads2.wikiart.org/00244/images/anci...
# 6  https://uploads0.wikiart.org/00244/images/anci...
# 7  https://uploads6.wikiart.org/00244/images/anci...
# 8  https://uploads5.wikiart.org/00244/images/anci...
# 9  https://uploads2.wikiart.org/00244/images/anci...

# %%
wikiart_original['Style'].value_counts()
# Out:
# Romanticism                          3600
# Impressionism                        3600
# Baroque                              3600
# Neoclassicism                        3600
# Realism                              3600
#                                      ...
# Graffiti-Art                            1
# Early-Christian                         1
# nd-Intermediate-Period                  1
# New-media-art                           1
# Stroganov-school-of-icon-painting       1
# Name: Style, Length: 217, dtype: int64

# %%
wikiart_original['Link'][0] #Check if link is in the right format and accessible
# Out:
# 'https://uploads3.wikiart.org/00265/images/ancient-egyptian-painting/narmer-palette.jpg'

# %% [markdown]
# ## Cleaning the Date column

# %%
wikiart_original['Date'].value_counts()
# Out:
# XIX-XX cent.       5713
# XX cent.           5669
# XVIII-XIX cent.    2418
# XVIII cent.        1766
# XX-XXI cent.       1526
#                    ...
# 1742-1743             1
# 1740-1743             1
# 1738-1740             1
# 1735-1740             1
# 3050 BC               1
# Name: Date, Length: 2959, dtype: int64

# %%
wikiart_original[wikiart_original['Date'] == '?']

# I did a quick search online and it looks like these works done by Denis Peterson were completed around year 2007. Let's replace these ? values with 2007.
# TAKI 183 was active during late 1960s and early 1970s. Let's replace these ? values with 1970.
# Out:
#                 Style                         Artwork          Artist Date  \
# 112096  Hyper-Realism                      Apocalypse  Denis Peterson    ?
# 112097  Hyper-Realism   Can't Lose What You Never Had  Denis Peterson    ?
# 112098  Hyper-Realism                Cardboard Dreams  Denis Peterson    ?
# 112099  Hyper-Realism                    Dust to Dust  Denis Peterson    ?
# 112100  Hyper-Realism                     Neon Lights  Denis Peterson    ?
# 112101  Hyper-Realism                       Not Again  Denis Peterson    ?
# 112102  Hyper-Realism                        The Wall  Denis Peterson    ?
# 112103  Hyper-Realism  Tombstone Hand, Graveyard Mind  Denis Peterson    ?
# 112104  Hyper-Realism           Toothbrush and a Comb  Denis Peterson    ?
# 112105  Hyper-Realism                          Vortex  Denis Peterson    ?
# 116620     Street-art                       Metro Tag        TAKI 183    ?
# 116621     Street-art                           Print        TAKI 183    ?
# 116622     Street-art                           Print        TAKI 183    ?
# 116623     Street-art        Taki 183 Spawns Pen Pals        TAKI 183    ?
# 116624     Street-art                  Untitled Print        TAKI 183    ?
# 116625     Street-art                        Untitled        TAKI 183    ?
# 116626     Street-art                        Untitled        TAKI 183    ?
#
#                                                      Link
# 112096  https://uploads4.wikiart.org/images/denis-pete...
# 112097  https://uploads5.wikiart.org/images/denis-pete...
# 112098  https://uploads1.wikiart.org/images/denis-pete...
# 112099  https://uploads6.wikiart.org/images/denis-pete...
# 112100  https://uploads5.wikiart.org/images/denis-pete...
# 112101  https://uploads8.wikiart.org/images/denis-pete...
# 112102  https://uploads2.wikiart.org/images/denis-pete...
# 112103  https://uploads5.wikiart.org/images/denis-pete...
# 112104  https://uploads6.wikiart.org/images/denis-pete...
# 112105  https://uploads0.wikiart.org/images/denis-pete...
# 116620  https://uploads6.wikiart.org/images/taki-183/m...
# 116621  https://uploads2.wikiart.org/images/taki-183/p...
# 116622  https://uploads4.wikiart.org/images/taki-183/p...
# 116623  https://uploads3.wikiart.org/images/taki-183/t...
# 116624  https://uploads2.wikiart.org/images/taki-183/u...
# 116625  https://uploads5.wikiart.org/images/taki-183/u...
# 116626  https://uploads7.wikiart.org/images/taki-183/u...

# %%
wikiart = wikiart_original.copy()
wikiart.loc[112096:112105, 'Date'] = np.repeat('2007',10)
wikiart.loc[116620:116626, 'Date'] = np.repeat('1970',7)
wikiart[wikiart['Artwork'] == 'Metro Tag'] # Verify
# Out:
#              Style    Artwork    Artist  Date  \
# 116620  Street-art  Metro Tag  TAKI 183  1970
#
#                                                      Link
# 116620  https://uploads6.wikiart.org/images/taki-183/m...

# %% [markdown]
# It looks like some values in the Dates column need to be changed for analysis purposes, such as "VII-VIII cent.", "1427-1400 BC", "35 BC", "1503-1519", "100 BC - 100 AD".
#
# To break it down, we need to:
#
# 1. Change Roman Numerals to Numbers: For values like "VII-VIII cent.", I need to convert Roman numerals to Arabic numbers.
# 2. Handle Date Ranges: For ranges such as "1427-1400 BC", I will compute the average of the two numbers and replace the range with that average.
# 3. Handle BC Dates: For dates with "BC", I will convert the number into its negative form.

# %% [markdown]
# ## Step 1: Convert Roman Numerals to Numbers

# %%
def roman_to_number(s):
    roman_numerals = {'I': 1, 'V': 5, 'X': 10, 'L': 50, 'C': 100, 'D': 500, 'M': 1000}
    num = 0
    prev_value = 0
    for i in s:
        if roman_numerals[i] > prev_value:
            num += roman_numerals[i] - 2 * prev_value
        else:
            num += roman_numerals[i]
        prev_value = roman_numerals[i]
    return num

# %% [markdown]
# ## Step 2: Handle Date Ranges

# %%
def handle_date_range(date_str):
    if '-' in date_str:
        start, end = date_str.split('-')
        start, end = int(start), int(end)
        return (start + end) // 2
    return int(date_str)

# %% [markdown]
# ## Step 3: Handle BC Dates

# %%
def handle_bc(date_str):
    if 'BC' in date_str:
        return -int(date_str.replace('BC', '').strip())
    return int(date_str)

# %% [markdown]
# ## Step 4: Applying the Changes

# %%
def process_date(date_str):
    # Handle mixed AD and BC dates with ranges, like "100 BC-100 AD"
    if 'AD' in date_str and 'BC' in date_str:
        start, end = date_str.split('-')
        start = -int(start.replace('BC', '').strip())  # Convert BC to negative
        end = int(end.replace('AD', '').strip())
        return (start + end) // 2
    
    # Handle BC dates with ranges, like "3100-2900 BC"
    elif 'BC' in date_str and '-' in date_str:
        date_without_bc = date_str.replace('BC', '').strip()
        avg_date = handle_date_range(date_without_bc)
        return -avg_date  # Convert to negative since it's BC
    
    # Handle BC dates without ranges
    elif 'BC' in date_str:
        return handle_bc(date_str)
    
    # Handle singular roman numeral dates like "XX cent."
    elif 'cent.' in date_str and '-' not in date_str:
        century_value = roman_to_number(date_str.replace('cent.', '').strip()) * 100
        # For values like "XX cent.", use 2023 to calculate midpoint, so we can avoid having 2050 as our artwork date
        if century_value == 2100:
            century_value = 2023
        return century_value - 50  # Assuming middle of century
    
    # Handle roman numeral date ranges like "VII-VIII cent."
    elif 'cent.' in date_str:
        start, end = date_str.replace('cent.', '').split('-')
        start, end = roman_to_number(start.strip()) * 100, roman_to_number(end.strip()) * 100
        # For values like "XX - XXI cent.", use 2023 to calculate midpoint, so we can avoid having 2050 as our artwork date
        if end == 2100:
            end = 2023
        return (start + end) // 2
    
    # Handle date ranges without BC
    elif '-' in date_str:
        return handle_date_range(date_str)
    
    # For all other dates
    else:
        return int(date_str.strip())

# Apply the final transformations
wikiart['Date'] = wikiart['Date'].apply(process_date)

# Display the first few rows of the modified data
wikiart.head()
# Out:
#             Style                                    Artwork         Artist  \
# 0  Early-Dynastic                             Narmer Palette  Ancient Egypt
# 1  Early-Dynastic         Box Inlay with a Geometric Pattern  Ancient Egypt
# 2     Old-Kingdom                           Khafre Enthroned  Ancient Egypt
# 3  Middle-Kingdom  Stele of the Serpent King (Stela of Djet)  Ancient Egypt
# 4  Middle-Kingdom  Laden Donkeys and Ploughing, Tomb of Djar  Ancient Egypt
#
#    Date                                               Link
# 0 -3050  https://uploads3.wikiart.org/00265/images/anci...
# 1 -3000  https://uploads2.wikiart.org/00244/images/anci...
# 2 -2570  https://uploads2.wikiart.org/00305/images/anci...
# 3 -3000  https://uploads7.wikiart.org/00305/images/anci...
# 4 -2035  https://uploads8.wikiart.org/00244/images/anci...

# %% [markdown]
# ## Verification

# %%
wikiart['Date'].describe()
# Out:
# count    124170.000000
# mean       1856.379222
# std         231.414707
# min       -3050.000000
# 25%        1850.000000
# 50%        1919.000000
# 75%        1962.000000
# max        2021.000000
# Name: Date, dtype: float64

# %%
wikiart.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 124170 entries, 0 to 124169
# Data columns (total 5 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   Style    124170 non-null  object
#  1   Artwork  124170 non-null  object
#  2   Artist   124170 non-null  object
#  3   Date     124170 non-null  int64
#  4   Link     124170 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 4.7+ MB

# %%
wikiart_original[wikiart_original['Artwork'] == 'Transfiguration, wall painting']
# Out:
#           Style                         Artwork             Artist  \
# 1256  Byzantine  Transfiguration, wall painting  Jerzy Nowosielski
#
#               Date                                               Link
# 1256  XX-XXI cent.  https://uploads0.wikiart.org/00128/images/jerz...

# %%
wikiart[wikiart['Artwork'] == 'Transfiguration, wall painting']
# Out:
#           Style                         Artwork             Artist  Date  \
# 1256  Byzantine  Transfiguration, wall painting  Jerzy Nowosielski  2011
#
#                                                    Link
# 1256  https://uploads0.wikiart.org/00128/images/jerz...

# %%
wikiart.to_csv('wikiart_cleaned.csv') # Save Cleaned Data

# %% [markdown]
# ## Popularity of Art Styles

# %% [markdown]
# ### 1. The 20 most popular art styles of all times

# %%
style = wikiart[['Style','Artwork']].groupby(['Style']).count().sort_values(by='Artwork', ascending = False)
style.reset_index(inplace = True)
style.head(20)
# Looks like the max number of a certain style in this dataset is 3600. Why? Might have to do with how the data was scraped from WikiArt?
# Out:
#                            Style  Artwork
# 0           Art-Nouveau-(Modern)     3600
# 1                      Symbolism     3600
# 2                        Baroque     3600
# 3                        Realism     3600
# 4                    Romanticism     3600
# 5                  Neoclassicism     3600
# 6                  Expressionism     3600
# 7             Post-Impressionism     3600
# 8                     Surrealism     3600
# 9        Naïve-Art-(Primitivism)     3600
# 10                 Impressionism     3600
# 11        Abstract-Expressionism     3600
# 12                        Rococo     3541
# 13                        Cubism     3403
# 14          Northern-Renaissance     3239
# 15                   Academicism     2769
# 16                       Pop-Art     2708
# 17  Mannerism-(Late-Renaissance)     2429
# 18                    Minimalism     2242
# 19                Conceptual-Art     2111

# %% [markdown]
# Let's add columns Earliest Artwork Date, Latest Artwork Date, and Average Date, which might be helpful for analysis

# %%
earliest = wikiart.groupby('Style').min().reset_index()[['Style','Date']]
latest = wikiart.groupby('Style').max().reset_index()[['Style','Date']]
average = wikiart.groupby('Style').mean().reset_index()[['Style','Date']]
style_merged = style.merge(earliest, on = 'Style').merge(latest, on = 'Style').merge(average, on = 'Style').sort_values(by = 'Date_x')
style_merged = style_merged.rename(columns={'Date_x':'Earliest Year','Date_y': 'Latest Year', 'Date':'Average Year'})
style_merged['Average Year'] = style_merged['Average Year'].astype(int)
style_merged
# Out:
# /var/folders/n1/23wv0mx94750hvp46v8gnvkh0000gn/T/ipykernel_94366/3048120314.py:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   average = wikiart.groupby('Style').mean().reset_index()[['Style','Date']]
#                       Style  Artwork  Earliest Year  Latest Year  Average Year
# 209          Early-Dynastic        2          -3050        -3000         -3025
# 198          Middle-Kingdom        9          -3000        -1721         -2025
# 214             Old-Kingdom        1          -2570        -2570         -2570
# 216  nd-Intermediate-Period        1          -1550        -1550         -1550
# 116             New-Kingdom      114          -1504        -1128         -1400
# ..                      ...      ...            ...          ...           ...
# 146               Queer-art       57           2001         2020          2011
# 212            Graffiti-Art        1           2002         2002          2002
# 195                Ero-guro       11           2011         2011          2011
# 213           New-media-art        1           2013         2013          2013
# 171        New-Ink-Painting       23           2014         2021          2019
#
# [217 rows x 5 columns]

# %% [markdown]
# ### 2. 20 Most Prolific Artists of All Times

# %%
wikiart[['Artist','Artwork']].groupby(['Artist']).count().sort_values(by='Artwork', ascending = False).head(20)
# Out:
#                             Artwork
# Artist
# Giovanni Battista Piranesi     1352
# Vincent van Gogh               1101
# Pablo Picasso                   992
# Alfred Freddy Krupa             923
# Albrecht Durer                  845
# Marc Chagall                    834
# Salvador Dali                   730
# Claude Monet                    692
# Rembrandt                       655
# Nicholas Roerich                546
# Henri Matisse                   537
# Byzantine Mosaics               493
# Paul Gauguin                    484
# Paul Cezanne                    472
# Camille Pissarro                452
# Pierre-Auguste Renoir           449
# Fernand Leger                   442
# Sam Francis                     426
# Eyvind Earle                    422
# Peter Paul Rubens               421

# %% [markdown]
# ## Trends in Art Over Time

# %% [markdown]
# ### 1. Trend in Number of Artworks Over Time

# %%
fig = px.histogram(wikiart,x='Date',nbins=int((2023 + 3050) / 20))
fig.show()

# %% [markdown]
# **There seems to be very large number of artworks produced between 1900 - 1999 in this dataset. There could be a number of reasons**
# 1) the way the data was scraped
# 2) it is harder to access and preserve artworks produced earlier than 1900
# 3) in the 20th century, changes in art forms and concepts have made art more accessible to the general public (i.e. the invention of cameras, rising popularity of graffiti art as well as how modern art appreciates using ready-made objects to create artworks)

# %%
fig = px.bar(style_merged, x = 'Artwork', y = 'Style', animation_frame='Average Year',title='Trends in Art Styles Over Time')
fig.show()
